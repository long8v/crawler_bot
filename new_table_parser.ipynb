# %%
from crawl_utils.table_parser import *

# %%
url = 'http://www.0415599999.com/bbs/content.php?co_id=0106'

# %%
table_parsing(url)[5]
# Out:
#            0      1                     2     3                  4
# 1   상급병실료 차액  상급병실료             병실차액(1인실)    1일            100,000
# 2   상급병실료 차액  상급병실료             병실차액(2인실)    1일             70,000
# 3        약제비    내복약               트레스탄 캅셀    개당              1,000
# 4        약제비    내복약                 액티피드정    개당                 60
# 5        약제비    내복약                   삐콤정    개당                 40
# 6        약제비    내복약                   토파제    개당              1,000
# 7        약제비    내복약                 푸리타제정    개당                200
# 8        약제비    내복약               속시나제삼중정    개당                200
# 9        약제비    내복약                  베아제정    개당                300
# 10       약제비    외용약                오라메디연고    개당              7,000
# 11       약제비    외용약                 후시딘연고    개당              7,000
# 12       약제비    외용약            니조랄액 100ml    개당             15,000
# 13       약제비    외용약                마데카솔분말    개당             10,000
# ...

# %%
table_list[5]
# Out:
#           분류   세부항목                  세부항목    단위                 비용
# 1   상급병실료 차액  상급병실료             병실차액(1인실)    1일            100,000
# 2   상급병실료 차액  상급병실료             병실차액(2인실)    1일             70,000
# 3        약제비    내복약               트레스탄 캅셀    개당              1,000
# 4        약제비    내복약                 액티피드정    개당                 60
# 5        약제비    내복약                   삐콤정    개당                 40
# 6        약제비    내복약                   토파제    개당              1,000
# 7        약제비    내복약                 푸리타제정    개당                200
# 8        약제비    내복약               속시나제삼중정    개당                200
# 9        약제비    내복약                  베아제정    개당                300
# 10       약제비    외용약                오라메디연고    개당              7,000
# 11       약제비    외용약                 후시딘연고    개당              7,000
# 12       약제비    외용약            니조랄액 100ml    개당             15,000
# 13       약제비    외용약                마데카솔분말    개당             10,000
# ...
