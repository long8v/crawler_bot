# %%
import numpy as np
import pandas as pd
from collections import Counter
from crawl_utils.url_extractor import *
from crawl_utils.table_parser import *
from crawl_utils.html_request import *
from crawl_utils.create_table import *
from crawl_utils.html_parser import *

# %%
link = 'http://www.kjhd.co.kr/'

# %%
def sub_pages(url, visited=set([]), show_javascript=False):
    '''
    input : url(str)
    output : list of tuples(text, href)
    
    get sub pages given url
    '''
    sub_pages = []
    java_pages = []
    if url.startswith("http"):
        parsed = parsing(url)
        if parsed:
            for _ in parsed.select('div'):
                if _.has_attr('onclick'):
                    try:
                        sub_pages.append((_.text, urljoin(url, _["onclick"].split("href=")[1].replace("'","").replace(";", ""))))
                    except:
                        pass
            for _ in parsed.select('a'):

                if _.has_attr("href") and "#" not in _["href"] and not is_portal(_["href"]):
                    if 'javascript' in _['href'].lower():
                        java_pages.append((url, _["href"]))
                    if _["href"].startswith('http'):
                        link = _["href"]    
                    else: 
                        link = urljoin(url, _["href"])
                    if link not in visited:
                        if not _.text.strip():
                            sub_pages.append(("_".join([img["alt"] 
                            if img.has_attr('alt')
                            else ""
                            for img in _.find_all('img')
                            ]), link))
                        else:
                            print(_.text, link)
                            sub_pages.append((_.text, link))
                        visited.update([link])
    if java_pages and show_javascript:
        print(url, len(java_pages))
    return sub_pages, visited

# %%
sub_pages(link)
# Out:
# http://www.kjhd.co.kr
#
# 로고 관리   http://www.kjhd.co.kr
# http://www.kjhd.co.kr
# 병원소개 http://kjhd.co.kr/bbs/board.php?bo_table=vision
# http://www.kjhd.co.kr
# 진료안내 http://kjhd.co.kr/bbs/board.php?bo_table=treatment_guide
# http://www.kjhd.co.kr
# 인공관절센터 http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis_center
# http://www.kjhd.co.kr
# 건강검진센터 http://kjhd.co.kr/bbs/board.php?bo_table=checkup_guide
# http://www.kjhd.co.kr
# 이용안내 http://kjhd.co.kr/bbs/board.php?bo_table=hospitalization_guid
# http://www.kjhd.co.kr
# 인사말 http://kjhd.co.kr/bbs/board.php?bo_table=intro
# http://www.kjhd.co.kr
# 층별안내 http://kjhd.co.kr/bbs/board.php?bo_table=floor_plans
# http://www.kjhd.co.kr
# 오시는 길 http://kjhd.co.kr/bbs/board.php?bo_table=map
# http://www.kjhd.co.kr
# 의료장비 안내 http://kjhd.co.kr/bbs/board.php?bo_table=medical_device
# http://www.kjhd.co.kr
# 진료시간 안내 http://kjhd.co.kr/bbs/board.php?bo_table=consultation_hours
# http://www.kjhd.co.kr
# 인공관절이란? http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis
# http://www.kjhd.co.kr
# 내비게이션인공관절 수술이란? http://kjhd.co.kr/bbs/board.php?bo_table=navigation
# http://www.kjhd.co.kr
#   ('국민건강검진 안내', 'http://kjhd.co.kr/bbs/board.php?bo_table=health_checkup'),
#   ('증명서 발급 안내', 'http://kjhd.co.kr/bbs/board.php?bo_table=certificate'),
#   ('비급여 진료 비용 안내', 'http://kjhd.co.kr/bbs/board.php?bo_table=unpaid'),
#   ('전화번호 안내', 'http://kjhd.co.kr/bbs/board.php?bo_table=telephone_guide'),
#   ('채용정보', 'http://kjhd.co.kr/bbs/board.php?bo_table=employment_info'),
#   ('자주하는 질문', 'http://kjhd.co.kr/bbs/board.php?bo_table=faq'),
#   ('', 'http://kjhd.co.kr'),
#   ('.', 'http://www.kjhd.co.kr/bbs/login.php')],
#  {'http://kjhd.co.kr',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=care_guide',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=certificate',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=checkup_chart',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=checkup_guide',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=consultation_hours',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=employment_info',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=faq',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=floor_plans',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=health_checkup',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=hospitalization_guid',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=inquiry',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=intro',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=map',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=medical_device',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=navigation',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis_center',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=surgical_procedures',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=telephone_guide',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=treatment_guide',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=unpaid',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=vision',
#   'http://www.kjhd.co.kr',
#   'http://www.kjhd.co.kr/bbs/login.php'})

# %%
for _ in parsing(link).find_all('a'):
    if _.has_attr('href'):
        print(_["href"], _.text)
# Out:
# http://www.kjhd.co.kr
# 로고 관리
# http://kjhd.co.kr/bbs/board.php?bo_table=vision 병원소개
# http://kjhd.co.kr/bbs/board.php?bo_table=treatment_guide 진료안내
# http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis_center 인공관절센터
# http://kjhd.co.kr/bbs/board.php?bo_table=checkup_guide 건강검진센터
# http://kjhd.co.kr/bbs/board.php?bo_table=hospitalization_guid 이용안내
# http://kjhd.co.kr/bbs/board.php?bo_table=news 고객센터
# http://kjhd.co.kr/bbs/board.php?bo_table=vision 미션과 비전
# http://kjhd.co.kr/bbs/board.php?bo_table=intro 인사말
# http://kjhd.co.kr/bbs/board.php?bo_table=floor_plans 층별안내
# http://kjhd.co.kr/bbs/board.php?bo_table=map 오시는 길
# http://kjhd.co.kr/bbs/board.php?bo_table=treatment_guide 진료과목 안내
# http://kjhd.co.kr/bbs/board.php?bo_table=medical_device 의료장비 안내
# http://kjhd.co.kr/bbs/board.php?bo_table=consultation_hours 진료시간 안내
# http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis_center 인공관절센터 소개
# http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis 인공관절이란?
# http://kjhd.co.kr/bbs/board.php?bo_table=navigation 내비게이션인공관절 수술이란?
# http://kjhd.co.kr/bbs/board.php?bo_table=inquiry 상담문의
# http://kjhd.co.kr/bbs/board.php?bo_table=surgical_procedures 인공관절 수술 절차
# http://kjhd.co.kr/bbs/board.php?bo_table=care_guide 입·퇴원 시 치료
# http://kjhd.co.kr/bbs/board.php?bo_table=checkup_guide 건강검진 안내
# http://kjhd.co.kr/bbs/board.php?bo_table=checkup_chart 건강검진 순서도
# http://kjhd.co.kr/bbs/board.php?bo_table=health_checkup 국민건강검진 안내
# http://kjhd.co.kr/bbs/board.php?bo_table=hospitalization_guid 입·퇴원 안내
# http://kjhd.co.kr/bbs/board.php?bo_table=certificate 증명서 발급 안내
# http://kjhd.co.kr/bbs/board.php?bo_table=unpaid 비급여 진료 비용 안내
# http://kjhd.co.kr/bbs/board.php?bo_table=telephone_guide 전화번호 안내
# http://kjhd.co.kr/bbs/board.php?bo_table=news 병원소식
# http://kjhd.co.kr/bbs/board.php?bo_table=employment_info 채용정보
# http://kjhd.co.kr/bbs/board.php?bo_table=faq 자주하는 질문
# http://kjhd.co.kr/bbs/board.php?bo_table=checkup_guide
# http://kjhd.co.kr
# http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis_center
# http://kjhd.co.kr/bbs/board.php?bo_table=checkup_guide
# http://kjhd.co.kr/bbs/board.php?bo_table=certificate
# http://kjhd.co.kr/bbs/board.php?bo_table=consultation_hours
# http://kjhd.co.kr/bbs/board.php?bo_table=hospitalization_guid
# http://kjhd.co.kr/bbs/board.php?bo_table=treatment_guide
# http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis_center
# http://kjhd.co.kr/bbs/board.php?bo_table=telephone_guide
# http://kjhd.co.kr/bbs/board.php?bo_table=medical_device
# http://kjhd.co.kr/bbs/board.php?bo_table=floor_plans
# http://kjhd.co.kr/bbs/board.php?bo_table=faq
# http://kjhd.co.kr/bbs/board.php?bo_table=map
# http://www.kjhd.co.kr/bbs/board.php?bo_table=news 병원소식
# http://www.kjhd.co.kr/bbs/board.php?bo_table=news&wr_id=25 무릎 인공관절 수술 후 다리 굴곡운동(CPM) 중이신 환자분들
# http://www.kjhd.co.kr/bbs/board.php?bo_table=news&wr_id=24 직원회의
# http://www.kjhd.co.kr/bbs/board.php?bo_table=news
# http://www.kjhd.co.kr/bbs/login.php .
# https://www.instagram.com/kjhd_hospital/ instagram

# %%
sub_pages(link)
# Out:
# ([('\n로고 관리\xa0 ', 'http://www.kjhd.co.kr'),
#   ('.', 'http://www.kjhd.co.kr/bbs/login.php')],
#  {'http://kjhd.co.kr',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=care_guide',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=certificate',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=checkup_chart',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=checkup_guide',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=consultation_hours',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=employment_info',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=faq',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=floor_plans',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=health_checkup',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=hospitalization_guid',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=inquiry',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=intro',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=map',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=medical_device',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=navigation',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=nearthrosis_center',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=surgical_procedures',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=telephone_guide',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=treatment_guide',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=unpaid',
#   'http://kjhd.co.kr/bbs/board.php?bo_table=vision',
#   'http://www.kjhd.co.kr',
#   'http://www.kjhd.co.kr/bbs/login.php'})
