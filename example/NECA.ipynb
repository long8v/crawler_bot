# %%
import re
import numpy as np
import pandas as pd
from tqdm import tqdm
from collections import Counter
from crawl_utils.bot_utils import *
from crawl_utils.html_request import *
from crawl_utils.url_extractor import *
from crawl_utils.table_parser import *
from crawl_utils.column_regularization import *
from crawl_utils.create_table import *

# %%
url = 'https://nhta.neca.re.kr/nhta/application/nhtaU0509L.ecg'

# %%
display_start()

# %%
driver = get_driver(url)

# %%
table = []
for _ in parsing(url).find_all('a'):
    if _.has_attr('onclick'):
        if 'move' in _['onclick']:
            driver.execute_script(_['onclick'])
            table.append(table_parsing(driver, use_selenium=True, is_driver=True))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/anaconda3/envs/long37v/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     155         try:
# --> 156             conn = connection.create_connection(
#     157                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/anaconda3/envs/long37v/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/anaconda3/envs/long37v/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...
